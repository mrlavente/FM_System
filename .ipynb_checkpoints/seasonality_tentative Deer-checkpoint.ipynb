# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data.csv")
data = data[data['species_name'] == "Aceros waldeni (Visayan Writhed Hornbill)"]
data=data[['date_report','no_observation']]
data.head()
# Out:
#   date_report  no_observation
# 1  2016-01-11              17
# 2  2016-01-12              10
# 3  2016-01-18              17
# 5  2016-01-12              12
# 9  2016-02-15              12

# %%
data.index = pd.to_datetime(data['date_report'])
data.drop(columns='date_report',inplace=True)
data.head()
data = data.resample('M').sum()
data
# Out:
#              no_observation
# date_report
# 2016-01-31               56
# 2016-02-29               41
# 2016-03-31               41
# 2016-04-30               45
# 2016-05-31               39
# ...                     ...
# 2021-08-31               58
# 2021-09-30               73
# 2021-10-31               29
# 2021-11-30               25
# 2021-12-31               26
#
# [72 rows x 1 columns]

# %%
data.isna().sum()
# Out:
# no_observation    0
# dtype: int64

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='date_report'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_data = seasonal_decompose(data, model="additive")
decompose_data.plot();

# %%
seasonality=decompose_data.seasonal
seasonality.plot(color='green')
# Out:
# <AxesSubplot:xlabel='date_report'>

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(data.no_observation, autolag = 'AIC')
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
print("5. Critical Values :")
for key, val in dftest[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  -2.187836473394911
# 2. P-Value :  0.2106896970953071
# 3. Num Of Lags :  11
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 60
# 5. Critical Values :
# 	 1% :  -3.5443688564814813
# 	 5% :  -2.9110731481481484
# 	 10% :  -2.5931902777777776

# %%
rolling_mean = data.rolling(window = 12).mean()
data['rolling_mean_diff'] = rolling_mean - rolling_mean.shift()
ax1 = plt.subplot()
data['rolling_mean_diff'].plot(title='after rolling mean & differencing');
ax2 = plt.subplot()
data.plot(title='original');

# %%
dftest = adfuller(data['rolling_mean_diff'].dropna(), autolag = 'AIC')
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
print("5. Critical Values :")
for key, val in dftest[4].items():
  print("\t",key, ": ", val)
# Out:
# 1. ADF :  -8.681935135372791
# 2. P-Value :  4.262857673055344e-14
# 3. Num Of Lags :  0
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 59
# 5. Critical Values :
# 	 1% :  -3.5463945337644063
# 	 5% :  -2.911939409384601
# 	 10% :  -2.5936515282964665

# %%
from statsmodels.tsa.arima_model import ARIMA
import warnings
warnings.filterwarnings("ignore")

model=ARIMA(data['no_observation'],order=(1,1,1))
history=model.fit()

# %%
history.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:       D.no_observation   No. Observations:                   71
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -276.644
# Method:                       css-mle   S.D. of innovations             11.645
# Date:                Sat, 27 Nov 2021   AIC                            561.288
# Time:                        14:19:37   BIC                            570.339
# Sample:                    02-29-2016   HQIC                           564.887
#                          - 12-31-2021
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.0449      0.128     -0.352      0.725      -0.295       0.205
# ar.L1.D.no_observation     0.5009      0.107      4.671      0.000       0.291       0.711
# ma.L1.D.no_observation    -1.0000      0.036    -27.698      0.000      -1.071      -0.929
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.9964           +0.0000j            1.9964            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# """

# %%
model_fit=model.fit()
data['forecast']=model_fit.predict(start=60,end=72,dynamic=True)
data[['no_observation','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='date_report'>

# %%
model=ARIMA(data['rolling_mean_diff'].dropna(),order=(1,1,1))
model_fit=model.fit()

# %%
data['forecast']=model_fit.predict(start=60,end=72,dynamic=True)
data[['rolling_mean_diff','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='date_report'>

# %%
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(data['no_observation'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()

# %%
data['forecast']=results.predict(start=60,end=72,dynamic=True)
data[['no_observation','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='date_report'>

# %%
from pandas.tseries.offsets import DateOffset
pred_date=[data.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
pred_date=pd.DataFrame(index=pred_date[1:],columns=data.columns)
pred_date
# Out:
#            no_observation rolling_mean_diff forecast
# 2022-01-31            NaN               NaN      NaN
# 2022-02-28            NaN               NaN      NaN
# 2022-03-31            NaN               NaN      NaN
# 2022-04-30            NaN               NaN      NaN
# 2022-05-31            NaN               NaN      NaN
# 2022-06-30            NaN               NaN      NaN
# 2022-07-31            NaN               NaN      NaN
# 2022-08-31            NaN               NaN      NaN
# 2022-09-30            NaN               NaN      NaN
# 2022-10-31            NaN               NaN      NaN
# 2022-11-30            NaN               NaN      NaN
# 2022-12-31            NaN               NaN      NaN
# 2023-01-31            NaN               NaN      NaN
# 2023-02-28            NaN               NaN      NaN
# 2023-03-31            NaN               NaN      NaN
# 2023-04-30            NaN               NaN      NaN
# 2023-05-31            NaN               NaN      NaN
# 2023-06-30            NaN               NaN      NaN
# 2023-07-31            NaN               NaN      NaN
# 2023-08-31            NaN               NaN      NaN
# 2023-09-30            NaN               NaN      NaN
# 2023-10-31            NaN               NaN      NaN
# 2023-11-30            NaN               NaN      NaN

# %%
data=pd.concat([data,pred_date])

# %%
data['forecast'] = results.predict(start = 72, end = 96, dynamic= True)  
data[['no_observation', 'forecast']].plot(figsize=(12, 8))
data
# Out:
#            no_observation  rolling_mean_diff   forecast
# 2016-01-31             56                NaN        NaN
# 2016-02-29             41                NaN        NaN
# 2016-03-31             41                NaN        NaN
# 2016-04-30             45                NaN        NaN
# 2016-05-31             39                NaN        NaN
# ...                   ...                ...        ...
# 2023-07-31            NaN                NaN  51.387256
# 2023-08-31            NaN                NaN  60.217009
# 2023-09-30            NaN                NaN  70.473169
# 2023-10-31            NaN                NaN  32.827890
# 2023-11-30            NaN                NaN  28.985925
#
# [95 rows x 3 columns]

# %%
data.tail(24)
# Out:
#            Sightings  rolling_mean_diff   forecast
# 2020-12-01        14           0.333333  13.417592
# 2021-01-01       NaN                NaN  19.156141
# 2021-02-01       NaN                NaN  22.588168
# 2021-03-01       NaN                NaN  16.649268
# 2021-04-01       NaN                NaN  23.952552
# 2021-05-01       NaN                NaN  24.237454
# 2021-06-01       NaN                NaN  21.871807
# 2021-07-01       NaN                NaN  27.934331
# 2021-08-01       NaN                NaN  27.620513
# 2021-09-01       NaN                NaN  22.536849
# 2021-10-01       NaN                NaN  15.655288
# 2021-11-01       NaN                NaN  13.456678
# 2021-12-01       NaN                NaN  15.688931
# 2022-01-01       NaN                NaN  18.835747
# 2022-02-01       NaN                NaN  21.927462
# 2022-03-01       NaN                NaN  18.288748
# 2022-04-01       NaN                NaN  24.630024
# 2022-05-01       NaN                NaN  24.509540
# 2022-06-01       NaN                NaN  22.503484
# 2022-07-01       NaN                NaN  29.168315
# 2022-08-01       NaN                NaN  26.976009
# 2022-09-01       NaN                NaN  22.411783
# 2022-10-01       NaN                NaN  16.164228
# 2022-11-01       NaN                NaN  14.419898
