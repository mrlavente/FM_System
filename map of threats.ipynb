# %%
from folium import plugins
import folium
import pandas as pd
import numpy as np
from folium.plugins import HeatMap

data = pd.read_csv('data.csv')
print(data)

Hmap = folium.Map(location=[11.102947, 122.516279],
                    zoom_start = 10, tiles='Stamen Terrain') 

# Ensure you're handing it floats

data['coordinates_lat'] = data['coordinates_lat'].astype(float)
data['coordinates_lng'] = data['coordinates_lng'].astype(float)

# Filter the DF for rows, then columns, then remove NaNs

heat_df =data
heat_df = heat_df[['coordinates_lat', 'coordinates_lng']]
heat_df = heat_df.dropna(axis=0, subset=['coordinates_lat','coordinates_lng'])

heat_data = [[row['coordinates_lat'],row['coordinates_lng']] for index, row in heat_df.iterrows()]
gradient = {.44: 'red', .66: 'lime', 1: 'blue'}
# Plot it on the map
HeatMap(heat_data,gradient=gradient).add_to(Hmap)

# Display the map
Hmap
# Out:
#      Unnamed: 0  report_id                               species_name  \
# 0             0          1        Raflesia speciosa (Panay Rafflesia)
# 1             1          2  Aceros waldeni (Visayan Writhed Hornbill)
# 2             2          3  Aceros waldeni (Visayan Writhed Hornbill)
# 3             3          4  Aceros waldeni (Visayan Writhed Hornbill)
# 4             4          5          Sus cebifrons (Visayan Warty Pig)
# ..          ...        ...                                        ...
# 574         574        576        Raflesia speciosa (Panay Rafflesia)
# 575         575        577  Aceros waldeni (Visayan Writhed Hornbill)
# 576         576        578        Raflesia speciosa (Panay Rafflesia)
# 577         577        579  Aceros waldeni (Visayan Writhed Hornbill)
# 578         578        580          Sus cebifrons (Visayan Warty Pig)
#
#     date_report          location                              site  \
# 0    2016-01-04  Sibalom, Antique                   Brgy. Imparayan
# 1    2016-01-11  Sibalom, Antique  Sitio Igculibao, Brgy.  Cabladan
# 2    2016-01-12    Madalag, Aklan              Brgy. Maria Cristina
# 3    2016-01-18     Ibajay, Aklan                    Brgy. Capataga
# 4    2016-01-25    Malinao, Aklan                    Brgy. Aparicio
# ..          ...               ...                               ...
# 574  2021-11-08  Sibalom, Antique  Sitio Igculibao, Brgy.  Cabladan
# 575  2021-11-29  Sibalom, Antique                   Brgy. Imparayan
# 576  2021-12-08  Sibalom, Antique                   Brgy. Imparayan
# 577  2021-12-22  Sibalom, Antique  Sitio Igculibao, Brgy.  Cabladan
# 578  2020-11-24    Malinao, Aklan                    Brgy. Aparicio
#
#      no_observation mode_observation          threats  \
# 0                15             Seen  Loss of Habitat
# 1                17             Seen          Hunting
# 2                10     Heard & Seen  Loss of Habitat
# 3                17     Heard & Seen  Loss of Habitat
# 4                13     Heard & Seen  Loss of Habitat
# ..              ...              ...              ...
# 574              12             Seen  Loss of Habitat
# 575               8             Seen          Hunting
# 576              11             Seen  Loss of Habitat
# 577               9             Seen          Hunting
# 578               8     Heard & Seen  Loss of Habitat
#
#                           remarks name_observers  coordinates_lat  \
# 0                Seen at BMS site   Bantay Gubat        10.787310
# 1                Seen at BMS site     IP leaders        10.802552
# 2        Seen at the forest edges    Cenro Staff        11.526426
# 3                Seen at BMS site     IP leaders        11.815656
# 4    Seen in the area of Aparicio   Bantay Gubat        11.644341
# ..                            ...            ...              ...
# 574              Seen at BMS site    Cenro Staff        10.803932
# 575      Seen at the forest edges     IP leaders        10.803974
# 576              Seen at BMS site     IP leaders        10.790516
# 577         Seen at the tree tops   Bantay Gubat        10.791447
# 578  Seen in the area of Aparicio   Bantay Gubat        11.641020
#
#      coordinates_lng
# 0         122.104682
# 1         122.143548
# 2         122.309037
# 3         122.170886
# 4         122.305898
# ..               ...
# 574       122.142444
# 575       122.143207
# 576       122.104078
# 577       122.107009
# 578       122.307105
#
# [579 rows x 13 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_473ea67387e64af293ed6841e958307e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_473ea67387e64af293ed6841e958307e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_473ea67387e64af293ed6841e958307e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_473ea67387e64af293ed6841e958307e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
from folium import plugins
import folium
import pandas as pd
import numpy as np
from folium.plugins import HeatMap

data = pd.read_csv('data.csv')
data = data[data['species_name'] == "Raflesia speciosa (Panay Rafflesia)"]
data = data[data['threats'] == "Loss of Habitat"]
print(data)

Hmap = folium.Map(location=[11.102947, 122.516279],
                    zoom_start = 10, tiles='Stamen Terrain') 

# Ensure you're handing it floats

data['coordinates_lat'] = data['coordinates_lat'].astype(float)
data['coordinates_lng'] = data['coordinates_lng'].astype(float)

# Filter the DF for rows, then columns, then remove NaNs

heat_df =data
heat_df = heat_df[['coordinates_lat', 'coordinates_lng']]
heat_df = heat_df.dropna(axis=0, subset=['coordinates_lat','coordinates_lng'])

heat_data = [[row['coordinates_lat'],row['coordinates_lng']] for index, row in heat_df.iterrows()]
gradient = {.44: 'red', .66: 'lime', 1: 'blue'}
# Plot it on the map
HeatMap(heat_data,gradient=gradient).add_to(Hmap)

# Display the map
Hmap
# Out:
#      Unnamed: 0  report_id                         species_name date_report  \
# 0             0          1  Raflesia speciosa (Panay Rafflesia)  2016-01-04
# 8             8          9  Raflesia speciosa (Panay Rafflesia)  2016-02-01
# 16           16         17  Raflesia speciosa (Panay Rafflesia)  2016-03-07
# 32           32         33  Raflesia speciosa (Panay Rafflesia)  2016-05-02
# 40           40         41  Raflesia speciosa (Panay Rafflesia)  2016-06-06
# ..          ...        ...                                  ...         ...
# 568         568        570  Raflesia speciosa (Panay Rafflesia)  2021-08-08
# 570         570        572  Raflesia speciosa (Panay Rafflesia)  2021-09-04
# 572         572        574  Raflesia speciosa (Panay Rafflesia)  2021-10-06
# 574         574        576  Raflesia speciosa (Panay Rafflesia)  2021-11-08
# 576         576        578  Raflesia speciosa (Panay Rafflesia)  2021-12-08
#
#              location                              site  no_observation  \
# 0    Sibalom, Antique                   Brgy. Imparayan              15
# 8    Sibalom, Antique  Sitio Igculibao, Brgy.  Cabladan              12
# 16   Sibalom, Antique                   Brgy. Imparayan              14
# 32   Sibalom, Antique                   Brgy. Imparayan              16
# 40   Sibalom, Antique                   Brgy. Imparayan              18
# ..                ...                               ...             ...
# 568  Sibalom, Antique                   Brgy. Imparayan              20
# 570  Sibalom, Antique  Sitio Igculibao, Brgy.  Cabladan              24
# 572  Sibalom, Antique                   Brgy. Imparayan              25
# 574  Sibalom, Antique  Sitio Igculibao, Brgy.  Cabladan              12
# 576  Sibalom, Antique                   Brgy. Imparayan              11
#
#     mode_observation          threats           remarks name_observers  \
# 0               Seen  Loss of Habitat  Seen at BMS site   Bantay Gubat
# 8               Seen  Loss of Habitat  Seen at BMS site   Bantay Gubat
# 16              Seen  Loss of Habitat  Seen at BMS site   Bantay Gubat
# 32              Seen  Loss of Habitat  Seen at BMS site   Bantay Gubat
# 40              Seen  Loss of Habitat  Seen at BMS site     IP leaders
# ..               ...              ...               ...            ...
# 568             Seen  Loss of Habitat  Seen at BMS site    Cenro Staff
# 570             Seen  Loss of Habitat  Seen at BMS site   Bantay Gubat
# 572              See  Loss of Habitat  Seen at BMS site     IP leaders
# 574             Seen  Loss of Habitat  Seen at BMS site    Cenro Staff
# 576             Seen  Loss of Habitat  Seen at BMS site     IP leaders
#
#      coordinates_lat  coordinates_lng
# 0          10.787310       122.104682
# 8          10.803071       122.143549
# 16         10.790514       122.104079
# 32         10.793296       122.110007
# 40         10.787312       122.104682
# ..               ...              ...
# 568        10.803931       122.142845
# 570        10.793298       122.110005
# 572        10.787316       122.104687
# 574        10.803932       122.142444
# 576        10.790516       122.104078
#
# [71 rows x 13 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_77bbc4fa23bb4477a7ecc9bd43ee4a3f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_77bbc4fa23bb4477a7ecc9bd43ee4a3f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_77bbc4fa23bb4477a7ecc9bd43ee4a3f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_77bbc4fa23bb4477a7ecc9bd43ee4a3f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
from folium import plugins
import folium
import pandas as pd
import numpy as np
from folium.plugins import HeatMap

data = pd.read_csv('data.csv')
data = data[data['species_name'] == "Raflesia speciosa (Panay Rafflesia)"]
data = data[data['threats'] == "Hunting"]
print(data)

Hmap = folium.Map(location=[11.102947, 122.516279],
                    zoom_start = 10, tiles='Stamen Terrain') 

# Ensure you're handing it floats

data['coordinates_lat'] = data['coordinates_lat'].astype(float)
data['coordinates_lng'] = data['coordinates_lng'].astype(float)

# Filter the DF for rows, then columns, then remove NaNs

heat_df =data
heat_df = heat_df[['coordinates_lat', 'coordinates_lng']]
heat_df = heat_df.dropna(axis=0, subset=['coordinates_lat','coordinates_lng'])

heat_data = [[row['coordinates_lat'],row['coordinates_lng']] for index, row in heat_df.iterrows()]
gradient = {.44: 'red', .66: 'lime', 1: 'blue'}
# Plot it on the map
HeatMap(heat_data,gradient=gradient).add_to(Hmap)

# Display the map
Hmap
# Out:
#     Unnamed: 0  report_id                         species_name date_report  \
# 24          24         25  Raflesia speciosa (Panay Rafflesia)  2016-04-04
#
#             location                              site  no_observation  \
# 24  Sibalom, Antique  Sitio Igculibao, Brgy.  Cabladan              16
#
#    mode_observation  threats           remarks name_observers  \
# 24             Seen  Hunting  Seen at BMS site    Cenro Staff
#
#     coordinates_lat  coordinates_lng
# 24        10.803935       122.142841
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_48f11304cf534869a344637790b8ef92%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_48f11304cf534869a344637790b8ef92%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_48f11304cf534869a344637790b8ef92%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_48f11304cf534869a344637790b8ef92%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
from folium import plugins
import folium
import pandas as pd
import numpy as np
from folium.plugins import HeatMap

data = pd.read_csv('data.csv')
data = data[data['species_name'] == "Raflesia speciosa (Panay Rafflesia)"]
data = data[data['threats'] == "Loss of Habitat"]
print(data)

Hmap = folium.Map(location=[11.102947, 122.516279],
                    zoom_start = 10, tiles='Stamen Terrain') 

# Ensure you're handing it floats

data['coordinates_lat'] = data['coordinates_lat'].astype(float)
data['coordinates_lng'] = data['coordinates_lng'].astype(float)

# Filter the DF for rows, then columns, then remove NaNs

heat_df =data
heat_df = heat_df[['coordinates_lat', 'coordinates_lng']]
heat_df = heat_df.dropna(axis=0, subset=['coordinates_lat','coordinates_lng'])

heat_data = [[row['coordinates_lat'],row['coordinates_lng']] for index, row in heat_df.iterrows()]
gradient = {.44: 'red', .66: 'lime', 1: 'blue'}
# Plot it on the map
HeatMap(heat_data,gradient=gradient).add_to(Hmap)

# Display the map
Hmap

# %%
from folium import plugins
import folium
import pandas as pd
import numpy as np
from folium.plugins import HeatMap

data = pd.read_csv('data.csv')
data = data[data['species_name'] == "Raflesia speciosa (Panay Rafflesia)"]
data = data[data['threats'] == "Hunting"]
print(data)

Hmap = folium.Map(location=[11.102947, 122.516279],
                    zoom_start = 10, tiles='Stamen Terrain') 

# Ensure you're handing it floats

data['coordinates_lat'] = data['coordinates_lat'].astype(float)
data['coordinates_lng'] = data['coordinates_lng'].astype(float)

# Filter the DF for rows, then columns, then remove NaNs

heat_df =data
heat_df = heat_df[['coordinates_lat', 'coordinates_lng']]
heat_df = heat_df.dropna(axis=0, subset=['coordinates_lat','coordinates_lng'])

heat_data = [[row['coordinates_lat'],row['coordinates_lng']] for index, row in heat_df.iterrows()]
gradient = {.44: 'red', .66: 'lime', 1: 'blue'}
# Plot it on the map
HeatMap(heat_data,gradient=gradient).add_to(Hmap)

# Display the map
Hmap
